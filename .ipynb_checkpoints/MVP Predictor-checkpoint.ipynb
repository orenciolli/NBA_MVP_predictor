# %% [markdown]
# ## Introduction
# In this product, we'll attempt to predict the winner of the NBA MVP award based on data regarding previous contenders. The Most Valuable Player award is given out annually (at the end of each regular season) to the player deemed to have the largest impact on his team's success. The criteria for this award are not concrete, and (unfortunately for the purposes of prediction) there is no single formula used to determine the winner of the award.
#
# We will attempt to predict the `share` of points that each candidate in a given year receives using various regression models, and using this prediction, we will predict the player with the highest share of points to be the season's MVP.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#engineering
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

#prediction
from xgboost import XGBRegressor

# %% [markdown]
# ### Reading the Data
#
# The data we'll be using were retrieved from Basketball-Reference.com by David Yoo in [his MVP project](https://towardsdatascience.com/predicting-the-next-nba-mvp-using-machine-learning-62615bfcff75#a409), and include the top candidates for the MVP award from each year dating back to 1980.

# %%
full = pd.read_csv('data/nba_player_stats.csv')

# %% [markdown]
# For convenience, we'll also make a DataFrame called `winners` containing only players who won the award.

# %%
winners = full[full['Rank']=='1']

# %% [markdown]
# ### EDA and Feature engineering

# %% [markdown]
# While there is no concrete formula determining who the MVP will be, it's often said that the award is given to the best player on the best team. To investigate this, let's look at the `seed` column (note that a team's 'seed' is their team's ranking in their respective conference. In other words, the 1 seed is the team with the best record in the conference).

# %%
winners['seed'].value_counts()
# Out:
# 1.0    30
# 3.5     3
# 1.5     2
# 2.0     2
# 3.0     2
# 5.0     1
# 2.5     1
# 6.0     1
# Name: seed, dtype: int64

# %%
winners.plot(y = 'seed', kind = 'hist', ec = 'w')
plt.show()

# %% [markdown]
# It certainly seems that this adage has some weight to it. 30 of the winners (32 if we include those whose team was tied for the first seed) played for the team with the best record in their respective conference.
# But, being on the highest seeded team certainly doesn't guarantee winning the MVP award. As we can see, there are 143 players whose team was (at least tied for) the highest seed, yet only 32 of them won the award.

# %%
full[(full['seed'] == 1) |(full['seed'] == 1.5)]['Player'].count()
# Out:
# 143

# %% [markdown]
# And of course, a team's seed doesn't tell the whole story. There are often very small differences (perhaps only two or three games) separating the numer one seed from the number two or even number 3 seed. This makes it very difficult to say for certain which team was the "best" in a given season.
# To account for these differences, we'll consider a team's win/loss percentage (or the percentage of their games which they won), as this should minimize the impact of these potential differences.

# %%
winners.plot(y = 'W/L%', kind = 'hist', ec = 'w')
plt.show()

# %% [markdown]
# So, now we have a better idea of which teams could be called "the best", but how can we determine who their best player was?
# To do this, we'll create interaction terms between a few individual statistics and the team's win/loss percentage. We expect these variables to be useful predictors as they should account for the event that a player had an exceptional individual season and won the award despite the fact that they don't play for an exceptionally good team (such as Russell Westbrook in 2016).

# %%
full['pts w/l'] = full['PTS'] * full['W/L%']
full['usage w/l'] = full['usage_percentage'] * full['W/L%']
full['bpm w/l'] = full['box_plus_minus'] * full['W/L%']
full['per w/l'] = full['player_efficiency_rating'] * full['W/L%']
full['ws w/l'] = full['win_shares'] * full['W/L%']

# %% [markdown]
# Now, let's examine the correlation between the quantitative variables and a player's share of points won (our response variable).

# %%
quant = ['G', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'year', 'W', 'W/L%', 'seed', 'player_efficiency_rating',
       'true_shooting_percentage', 'three_point_attempt_rate',
       'free_throw_attempt_rate', 'offensive_rebound_percentage',
       'defensive_rebound_percentage', 'total_rebound_percentage',
       'assist_percentage', 'steal_percentage', 'block_percentage',
       'turnover_percentage', 'usage_percentage', 'offensive_win_shares',
       'defensive_win_shares', 'win_shares', 'win_shares_per_48_minutes',
       'offensive_box_plus_minus', 'defensive_box_plus_minus',
       'box_plus_minus', 'value_over_replacement_player', 'pts w/l', 'usage w/l', 'bpm w/l', 'per w/l', 'ws w/l']
corrs = []
for col in quant:
    correlation = full['Share'].corr(full[col])
    corrs.append((col, correlation))
corrs
# Out:
# [('G', 0.1101647252258609),
#  ('MP', 0.2135301527502754),
#  ('PTS', 0.43243187245815523),
#  ('TRB', 0.18888680964984403),
#  ('AST', 0.13043956143097862),
#  ('STL', 0.1263645752011784),
#  ('BLK', 0.13368286780379987),
#  ('FG%', 0.1542962189769657),
#  ('3P%', 0.04093444892647246),
#  ('FT%', 0.05907797011661234),
#  ('year', 0.11166380987705657),
#  ('W', 0.31771678724750246),
#  ('W/L%', 0.350305142381794),
#  ('seed', -0.32328254793416134),
#  ('player_efficiency_rating', 0.5998608511462092),
#  ('true_shooting_percentage', 0.2563702413917939),
#  ('three_point_attempt_rate', 0.07271968057813488),
#  ('free_throw_attempt_rate', 0.1396324140135507),
#  ('offensive_rebound_percentage', 0.025482041516701727),
#  ('defensive_rebound_percentage', 0.1829732783741592),
#  ('total_rebound_percentage', 0.14811638172867367),
#  ('assist_percentage', 0.15871002215018376),
#  ('steal_percentage', 0.09635959510590908),
#  ('block_percentage', 0.11944865064848896),
#  ('turnover_percentage', -0.092861598903022),
#  ('usage_percentage', 0.3668466621228646),
#  ('offensive_win_shares', 0.5230717727485652),
#  ('defensive_win_shares', 0.3357135198358847),
#  ('win_shares', 0.6185864576133692),
#  ('win_shares_per_48_minutes', 0.6003511689451928),
#  ('offensive_box_plus_minus', 0.5426298081536616),
#  ('defensive_box_plus_minus', 0.3283009597977803),
#  ('box_plus_minus', 0.6038939806915993),
#  ('value_over_replacement_player', 0.6313117116109677),
#  ('pts w/l', 0.6194177633533855),
#  ('usage w/l', 0.5536100065054166),
#  ('bpm w/l', 0.6709749411508947),
#  ('per w/l', 0.6598654299968906),
#  ('ws w/l', 0.6744310669101274)]

# %% [markdown]
# As we can see, none of the variables are strongly correlated with our response variable, but a few present a moderate correlation which could be useful in prediction. Namely, the interaction terms we defined (such as points * win/loss), statistics specifically made for measuring a player's impact (such as win shares), and some individual statistics like player efficiency rating.
# We'll save these variables in a list for later use.

# %%
correlated = [tup[0] for tup in corrs if abs(tup[1]) >= 0.6]

# %%
[tup for tup in corrs if abs(tup[1]) > 0.6]
# Out:
# [('win_shares', 0.6185864576133692),
#  ('win_shares_per_48_minutes', 0.6003511689451928),
#  ('box_plus_minus', 0.6038939806915993),
#  ('value_over_replacement_player', 0.6313117116109677),
#  ('pts w/l', 0.6194177633533855),
#  ('bpm w/l', 0.6709749411508947),
#  ('per w/l', 0.6598654299968906),
#  ('ws w/l', 0.6744310669101274)]

# %%
correlated
# Out:
# ['win_shares',
#  'win_shares_per_48_minutes',
#  'box_plus_minus',
#  'value_over_replacement_player',
#  'pts w/l',
#  'bpm w/l',
#  'per w/l',
#  'ws w/l']

# %% [markdown]
# Let's explore the relationship a little more closely

# %%
for col in correlated:
    full[[col, 'Share']].plot(kind = 'scatter', x = col, y = 'Share')

    plt.title(f"correlation between share and {col}")

# %% [markdown]
# Based on these graphs, it seems like there are typically two clear clusters of data: Players who receive a considerable share of the votes (where the relationship between the variables seems more clear), and those who only receieve a very small fraction of the votes.
#
# Since we only want to predict the winner, we'll narrow our investigation down to the frontrunners:

# %%
contenders = full[full['Share'] >= 0.2]

# %%
for col in correlated:
    contenders[[col, 'Share']].plot(kind = 'scatter', x = col, y = 'Share')

    plt.title(f"correlation between share and {col}")

# %% [markdown]
# Repeating our analysis of the correlation coefficients:

# %%
new_corrs = []
for col in correlated:
    correlation = contenders['Share'].corr(contenders[col])
    new_corrs.append((col, correlation))
new_corrs
# Out:
# [('win_shares', 0.48548503731274795),
#  ('win_shares_per_48_minutes', 0.5062752892787254),
#  ('box_plus_minus', 0.49151425216866723),
#  ('value_over_replacement_player', 0.49902935369073775),
#  ('pts w/l', 0.5718958628276524),
#  ('bpm w/l', 0.6083415359683468),
#  ('per w/l', 0.6441511995123581),
#  ('ws w/l', 0.5964859570705581)]

# %% [markdown]
# Since the subset of the data containing players who received larger shares of the vote is the one we are most interested in predicting (as it's always the subset containing the winner and immediate runners-up), we'll use these variables as our features.

# %%
correlated = [tup[0] for tup in new_corrs if abs(tup[1]) > 0.499]

# %% [markdown]
# ### Prediction

# %% [markdown]
# **Defining helpers**
# Now that we've identified our useful features, it's time to make our predictions.
# We'll start by defining some helper functions

# %%
def get_train(year, df):
    training = df[df['year'] != year]
    x_train = training[correlated]
    y_train = training['Share']
    
    test = df[df['year'] == year]
    x_test = test[correlated]
    y_test = test['Share']
    
    return x_train, y_train, x_test, y_test

# %%
full[correlated]
# Out:
#      win_shares_per_48_minutes  value_over_replacement_player  pts w/l  \
# 0                        0.227                            7.3  18.1536
# 1                        0.213                            6.8  19.3680
# 2                        0.173                            4.4  16.5500
# 3                        0.182                            4.8  15.8472
# 4                        0.148                            2.3  10.4904
# ..                         ...                            ...      ...
# 674                      0.248                            3.8  10.3246
# 675                      0.075                            3.4  10.4784
# 676                      0.153                            2.3   9.7383
# 677                      0.179                            3.8  14.5750
# 678                      0.238                            4.2  16.1944
#
#      bpm w/l  per w/l   ws w/l
# 0     5.2704  18.5196  10.8336
# 1     5.4720  18.2880   9.0000
# 2     1.9500  12.0000   5.3000
# 3     3.3480  15.2520   8.3328
# 4     0.8184  11.3832   6.6216
# ..       ...      ...      ...
# 674   3.5378  16.9670   8.1586
# 675   1.7464   9.2040   1.7464
# 676   1.9749  12.4623   4.0860
# 677   4.7223  14.1086   3.2648
# 678   4.7669  16.9780   5.7464
#
# [679 rows x 6 columns]

# %%
def predict_share(year, df, pred):
    X_train, Y_train, X_test, Y_test = get_train(year, df)
    players = df['Player']
    
    pred.fit(X_train, Y_train)
    predictions = pred.predict(X_test)
    
    out = X_test.copy()
    out['Actual share'] = Y_test
    out['Predicted share'] = predictions
    out['Player'] = players
    return out[['Actual share', 'Predicted share', 'Player']]

# %%
def name_mvp(df):
    return df.sort_values(by = 'Predicted share', ascending = False)['Player'].iloc[0]

# %%
def mvp_table(df, regressor):
    predicted_winners = pd.Series(
        [name_mvp(predict_share(year, full, regressor)) 
         for year in full.sort_values(by = 'year')['year'].unique()])
    
    winners = df[df['Rank'] == '1'].reset_index()
    final = winners[['year', 'Player']].rename({'Player': 'Actual MVP'}, axis = 1)
    final['Predicted MVP'] = predicted_winners
    
    final['Correct'] = final['Actual MVP'] == final['Predicted MVP']
    return final

# %% [markdown]
# **Predictor**

# %% [markdown]
# After some experimentation, it seems that a gradient boosted decision tree regressor (using XGboost) with the following hyperparameters produces the best predictions.

# %%
xgb_result = mvp_table(full,
                       XGBRegressor(n_estimators=10, max_depth= 1, learning_rate = 0.01, subsample=1, 
                                    colsample_bytree=1)
                      )
xgb_result
# Out:
#     year             Actual MVP          Predicted MVP  Correct
# 0   1980    Kareem Abdul-Jabbar    Kareem Abdul-Jabbar     True
# 1   1981          Julius Erving          Julius Erving     True
# 2   1982           Moses Malone          Julius Erving    False
# 3   1983           Moses Malone           Moses Malone     True
# 4   1984             Larry Bird             Larry Bird     True
# 5   1985             Larry Bird             Larry Bird     True
# 6   1986             Larry Bird             Larry Bird     True
# 7   1987          Magic Johnson          Magic Johnson     True
# 8   1988         Michael Jordan         Michael Jordan     True
# 9   1989          Magic Johnson          Magic Johnson     True
# 10  1990          Magic Johnson          Magic Johnson     True
# 11  1991         Michael Jordan         Michael Jordan     True
# 12  1992         Michael Jordan         Michael Jordan     True
# 13  1993        Charles Barkley        Charles Barkley     True
# 14  1994        Hakeem Olajuwon         David Robinson    False
# 15  1995         David Robinson         David Robinson     True
# 16  1996         Michael Jordan         Michael Jordan     True
# 17  1997            Karl Malone            Karl Malone     True
# 18  1998         Michael Jordan         Michael Jordan     True
# 19  1999            Karl Malone            Karl Malone     True
# 20  2000       Shaquille O'Neal       Shaquille O'Neal     True
# 21  2001          Allen Iverson       Shaquille O'Neal    False
# 22  2002             Tim Duncan             Tim Duncan     True
# 23  2003             Tim Duncan             Tim Duncan     True
# 24  2004          Kevin Garnett          Kevin Garnett     True
# 25  2005             Steve Nash      Amar'e Stoudemire    False
# 26  2006             Steve Nash          Dirk Nowitzki    False
# 27  2007          Dirk Nowitzki          Dirk Nowitzki     True
# 28  2008            Kobe Bryant          Kevin Garnett    False
# 29  2009           LeBron James           LeBron James     True
# 30  2010           LeBron James           LeBron James     True
# 31  2011           Derrick Rose           LeBron James    False
# 32  2012           LeBron James           LeBron James     True
# 33  2013           LeBron James           LeBron James     True
# 34  2014           Kevin Durant           Kevin Durant     True
# 35  2015          Stephen Curry          Stephen Curry     True
# 36  2016          Stephen Curry          Stephen Curry     True
# 37  2017      Russell Westbrook          Kawhi Leonard    False
# 38  2018           James Harden           James Harden     True
# 39  2019  Giannis Antetokounmpo  Giannis Antetokounmpo     True
# 40  2020  Giannis Antetokounmpo  Giannis Antetokounmpo     True
# 41  2021           Nikola Jokić           Nikola Jokić     True

# %% [markdown]
# The model produces a fairly accurate prediction for the winner of each year's award (correct about 81% of the time), but doesn't do a great job of predicting the actual vote share each candidate received.
